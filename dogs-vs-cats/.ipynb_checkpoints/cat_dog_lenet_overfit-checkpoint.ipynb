# %%
import tensorflow as tf
from imutils import paths
import os
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array, array_to_img
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
import numpy as np
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from tensorflow.keras import layers

# %%
# grab the list of images in our dataset directory, then initialize
# the list of data (i.e., images) and class images
print("[INFO] loading images...")
imagePaths = list(paths.list_images('dataset'))
data = []
labels = []
# Out:
# [INFO] loading images...

# %%
# loop over the image paths
for imagePath in imagePaths:
	# extract the class label from the filename
	label = imagePath.split(os.path.sep)[-2]
	# load the input image (224x224) and preprocess it
	image = load_img(imagePath, target_size=(224, 224))
	image = img_to_array(image)
	image = preprocess_input(image)

	# update the data and labels lists, respectively
	data.append(image)
	labels.append(label)

# convert the data and labels to NumPy arrays
data = np.array(data, dtype="float32")
labels = np.array(labels)

# %%
# perform one-hot encoding on the labels
lb = LabelBinarizer()
labels = lb.fit_transform(labels)
labels = to_categorical(labels)

# partition the data into training and testing splits using 75% of
# the data for training and the remaining 25% for testing
(trainX, testX, trainY, testY) = train_test_split(data, labels,
	test_size=0.20, stratify=labels, random_state=42)

# %%
model = tf.keras.models.Sequential([
    layers.Conv2D(filters=16, kernel_size=5, activation='relu', input_shape=(224,224,3)),
    layers.MaxPool2D(),
    layers.Conv2D(filters=32, kernel_size=5, activation='relu'),
    layers.MaxPool2D(),
    layers.Flatten(),
    layers.Dense(16, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(2, activation='softmax')
])

# %%
model.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 220, 220, 16)      1216
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 110, 110, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 106, 106, 32)      12832
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 53, 53, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 89888)             0
# _________________________________________________________________
# dense (Dense)                (None, 16)                1438224
# _________________________________________________________________
# dropout (Dropout)            (None, 16)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 34
# =================================================================
# Total params: 1,452,306
# Trainable params: 1,452,306
# Non-trainable params: 0
# _________________________________________________________________

# %%
H = model.fit(trainX, trainY, batch_size=32, validation_split=0.2, epochs=20)
# Out:
# Epoch 1/20
# 20/20 [==============================] - 1s 52ms/step - loss: 0.9076 - accuracy: 0.5172 - val_loss: 0.6942 - val_accuracy: 0.4812
# Epoch 2/20
# 20/20 [==============================] - 1s 47ms/step - loss: 0.6831 - accuracy: 0.5391 - val_loss: 0.6791 - val_accuracy: 0.5750
# Epoch 3/20
# 20/20 [==============================] - 1s 43ms/step - loss: 0.6577 - accuracy: 0.6078 - val_loss: 0.6642 - val_accuracy: 0.5750
# Epoch 4/20
# 20/20 [==============================] - 1s 44ms/step - loss: 0.6225 - accuracy: 0.6516 - val_loss: 0.6682 - val_accuracy: 0.5813
# Epoch 5/20
# 20/20 [==============================] - 1s 43ms/step - loss: 0.5800 - accuracy: 0.7031 - val_loss: 0.6550 - val_accuracy: 0.5813
# Epoch 6/20
# 20/20 [==============================] - 1s 43ms/step - loss: 0.4934 - accuracy: 0.7719 - val_loss: 0.7081 - val_accuracy: 0.5688
# Epoch 7/20
# 20/20 [==============================] - 1s 44ms/step - loss: 0.3819 - accuracy: 0.8297 - val_loss: 0.7208 - val_accuracy: 0.6000
# Epoch 8/20
# 20/20 [==============================] - 1s 47ms/step - loss: 0.2642 - accuracy: 0.9062 - val_loss: 0.8469 - val_accuracy: 0.6250
# Epoch 9/20
# 20/20 [==============================] - 1s 44ms/step - loss: 0.1532 - accuracy: 0.9391 - val_loss: 0.9568 - val_accuracy: 0.5688
# Epoch 10/20
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1286 - accuracy: 0.9469 - val_loss: 1.1674 - val_accuracy: 0.5688
# Epoch 11/20
# 20/20 [==============================] - 1s 46ms/step - loss: 0.0970 - accuracy: 0.9656 - val_loss: 1.3384 - val_accuracy: 0.5750
# Epoch 12/20
# 20/20 [==============================] - 1s 48ms/step - loss: 0.0794 - accuracy: 0.9812 - val_loss: 1.4259 - val_accuracy: 0.5938
# Epoch 13/20
# 20/20 [==============================] - 1s 48ms/step - loss: 0.0776 - accuracy: 0.9656 - val_loss: 1.6506 - val_accuracy: 0.5625
# Epoch 14/20
# 20/20 [==============================] - 1s 44ms/step - loss: 0.0818 - accuracy: 0.9734 - val_loss: 1.5045 - val_accuracy: 0.5500
# Epoch 15/20
# 20/20 [==============================] - 1s 44ms/step - loss: 0.0741 - accuracy: 0.9844 - val_loss: 1.7093 - val_accuracy: 0.5375
# Epoch 16/20
# 20/20 [==============================] - 1s 45ms/step - loss: 0.0553 - accuracy: 0.9781 - val_loss: 1.8380 - val_accuracy: 0.5562
# Epoch 17/20
# 20/20 [==============================] - 1s 51ms/step - loss: 0.0526 - accuracy: 0.9844 - val_loss: 1.8605 - val_accuracy: 0.5688
# Epoch 18/20
# 20/20 [==============================] - 1s 45ms/step - loss: 0.0428 - accuracy: 0.9859 - val_loss: 2.0125 - val_accuracy: 0.5625
# Epoch 19/20
# 20/20 [==============================] - 1s 45ms/step - loss: 0.0336 - accuracy: 0.9859 - val_loss: 2.2553 - val_accuracy: 0.5688
# Epoch 20/20
# 20/20 [==============================] - 1s 45ms/step - loss: 0.0476 - accuracy: 0.9859 - val_loss: 2.0546 - val_accuracy: 0.5625

# %%
# plot the training loss and accuracy
N = 20
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.savefig("learning_curve.png")

# %%
model.save("catdognet.h5")

# %%
# make predictions on the testing set
print("[INFO] evaluating network...")
predIdxs = model.predict(testX, batch_size=32)

model.evaluate(testX, testY)
# Out:
# [INFO] evaluating network...
# 7/7 [==============================] - 0s 18ms/step - loss: 1.6280 - accuracy: 0.6400
# [1.6279804706573486, 0.6399999856948853]

# %%
model(testX[2:3])
# Out:
# <tf.Tensor: shape=(1, 2), dtype=float32, numpy=array([[0.01156875, 0.9884312 ]], dtype=float32)>

# %%
array_to_img(trainX[0])
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F41D4395ED0>

# %%
trainY[0]
# Out:
# array([1., 0.], dtype=float32)

# %%
# test on new image
image = load_img('sample_image/5.jpg', target_size=(224, 224))
image = img_to_array(image)
image = preprocess_input(image)

# %%
array_to_img(image)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F41BC2EC550>

# %%
image.shape

# %%
prediction = model(image.reshape(-1,224,224,3))

# %%
np.argmax(prediction, axis=1)
