# %%
import tensorflow as tf
from imutils import paths
import os
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array, array_to_img
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
import numpy as np
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from tensorflow.keras import layers

# %%
# grab the list of images in our dataset directory, then initialize
# the list of data (i.e., images) and class images
print("[INFO] loading images...")
imagePaths = list(paths.list_images('dataset'))
data = []
labels = []
# Out:
# [INFO] loading images...

# %%
# loop over the image paths
for imagePath in imagePaths:
	# extract the class label from the filename
	label = imagePath.split(os.path.sep)[-2]
	# load the input image (224x224) and preprocess it
	image = load_img(imagePath, target_size=(224, 224))
	image = img_to_array(image)
	image = preprocess_input(image)

	# update the data and labels lists, respectively
	data.append(image)
	labels.append(label)

# convert the data and labels to NumPy arrays
data = np.array(data, dtype="float32")
labels = np.array(labels)

# %%
# perform one-hot encoding on the labels
lb = LabelBinarizer()
labels = lb.fit_transform(labels)
labels = to_categorical(labels)

# partition the data into training and testing splits using 75% of
# the data for training and the remaining 25% for testing
(trainX, testX, trainY, testY) = train_test_split(data, labels,
	test_size=0.20, stratify=labels, random_state=42)

# %%
model = tf.keras.models.Sequential([
    layers.Conv2D(filters=16, kernel_size=5, activation='relu', input_shape=(224,224,3)),
    layers.MaxPool2D(),
    layers.Conv2D(filters=32, kernel_size=5, activation='relu'),
    layers.MaxPool2D(),
    layers.Flatten(),
    layers.Dense(16, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(2, activation='softmax')
])

# %%
model.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 220, 220, 16)      1216
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 110, 110, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 106, 106, 32)      12832
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 53, 53, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 89888)             0
# _________________________________________________________________
# dense (Dense)                (None, 16)                1438224
# _________________________________________________________________
# dropout (Dropout)            (None, 16)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 34
# =================================================================
# Total params: 1,452,306
# Trainable params: 1,452,306
# Non-trainable params: 0
# _________________________________________________________________

# %%
H = model.fit(trainX, trainY, batch_size=32, validation_split=0.2, epochs=20)
# Out:
# Epoch 1/20
# 10/10 [==============================] - 2s 205ms/step - loss: 1.1824 - accuracy: 0.4969 - val_loss: 0.6860 - val_accuracy: 0.5125
# Epoch 2/20
# 10/10 [==============================] - 0s 43ms/step - loss: 0.6863 - accuracy: 0.5000 - val_loss: 0.6891 - val_accuracy: 0.5125
# Epoch 3/20
# 10/10 [==============================] - 0s 42ms/step - loss: 0.6728 - accuracy: 0.5125 - val_loss: 0.6876 - val_accuracy: 0.5125
# Epoch 4/20
# 10/10 [==============================] - 0s 43ms/step - loss: 0.6481 - accuracy: 0.5938 - val_loss: 0.6607 - val_accuracy: 0.5000
# Epoch 5/20
# 10/10 [==============================] - 0s 42ms/step - loss: 0.5632 - accuracy: 0.7250 - val_loss: 0.7145 - val_accuracy: 0.5625
# Epoch 6/20
# 10/10 [==============================] - 1s 58ms/step - loss: 0.4441 - accuracy: 0.8156 - val_loss: 0.7716 - val_accuracy: 0.6125
# Epoch 7/20
# 10/10 [==============================] - 1s 54ms/step - loss: 0.3999 - accuracy: 0.8344 - val_loss: 0.7430 - val_accuracy: 0.6625
# Epoch 8/20
# 10/10 [==============================] - 1s 51ms/step - loss: 0.2929 - accuracy: 0.8938 - val_loss: 0.8097 - val_accuracy: 0.6250
# Epoch 9/20
# 10/10 [==============================] - 0s 44ms/step - loss: 0.1752 - accuracy: 0.9563 - val_loss: 0.9349 - val_accuracy: 0.6125
# Epoch 10/20
# 10/10 [==============================] - 0s 45ms/step - loss: 0.1154 - accuracy: 0.9625 - val_loss: 0.9796 - val_accuracy: 0.7250
# Epoch 11/20
# 10/10 [==============================] - 0s 44ms/step - loss: 0.1050 - accuracy: 0.9594 - val_loss: 1.0851 - val_accuracy: 0.6875
# Epoch 12/20
# 10/10 [==============================] - 1s 51ms/step - loss: 0.0792 - accuracy: 0.9750 - val_loss: 1.1709 - val_accuracy: 0.6750
# Epoch 13/20
# 10/10 [==============================] - 0s 45ms/step - loss: 0.0467 - accuracy: 0.9969 - val_loss: 1.3185 - val_accuracy: 0.6250
# Epoch 14/20
# 10/10 [==============================] - 0s 45ms/step - loss: 0.0251 - accuracy: 0.9969 - val_loss: 1.4779 - val_accuracy: 0.5625
# Epoch 15/20
# 10/10 [==============================] - 1s 54ms/step - loss: 0.0244 - accuracy: 0.9937 - val_loss: 1.5714 - val_accuracy: 0.5750
# Epoch 16/20
# 10/10 [==============================] - 0s 44ms/step - loss: 0.0415 - accuracy: 0.9875 - val_loss: 1.4613 - val_accuracy: 0.6500
# Epoch 17/20
# 10/10 [==============================] - 0s 44ms/step - loss: 0.0345 - accuracy: 0.9906 - val_loss: 1.5721 - val_accuracy: 0.6000
# Epoch 18/20
# 10/10 [==============================] - 0s 44ms/step - loss: 0.0267 - accuracy: 0.9906 - val_loss: 1.7769 - val_accuracy: 0.6500
# Epoch 19/20
# 10/10 [==============================] - 0s 45ms/step - loss: 0.0241 - accuracy: 0.9969 - val_loss: 1.9249 - val_accuracy: 0.6000
# Epoch 20/20
# 10/10 [==============================] - 0s 44ms/step - loss: 0.0355 - accuracy: 0.9969 - val_loss: 1.8822 - val_accuracy: 0.6125

# %%
# plot the training loss and accuracy
N = 20
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.savefig("learning_curve.png")

# %%
model.save("catdognet.h5")

# %%
# make predictions on the testing set
print("[INFO] evaluating network...")
predIdxs = model.predict(testX, batch_size=32)

model.evaluate(testX, testY)
# Out:
# [INFO] evaluating network...
# 4/4 [==============================] - 0s 17ms/step - loss: 1.5943 - accuracy: 0.6000
# [1.5943058729171753, 0.6000000238418579]

# %%
model(testX[2:3])
# Out:
# <tf.Tensor: shape=(1, 2), dtype=float32, numpy=array([[0.08798416, 0.91201586]], dtype=float32)>

# %%
array_to_img(trainX[0])
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F3FE018F650>

# %%
trainY[0]
# Out:
# array([1., 0.], dtype=float32)

# %%
# test on new image
image = load_img('sample_image/5.jpg', target_size=(224, 224))
image = img_to_array(image)
image = preprocess_input(image)

# %%
array_to_img(image)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F3F9C082490>

# %%
image.shape
# Out:
# (224, 224, 3)

# %%
prediction = model(image.reshape(-1,224,224,3))

# %%
np.argmax(prediction, axis=1)
# Out:
# array([0])
